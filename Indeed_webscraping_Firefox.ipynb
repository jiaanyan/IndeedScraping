# %% [markdown]
# # Web Scraping - Indeed.com

# %% [markdown]
# ## Configure scraping settings
#
# NOTE: Please only modify the cell below before running this program

# %%
# 1.job position
# eg. data analyst, data scientist, data engineer, data develop, manager of analytics, director of analytics
position = "director of analytics"

# 2.job location
locations = "Toronto, ON"

# 3.Number of postings to scrape (200 is recommended)
postings = 30

# %% [markdown]
# ## Import Dependencies

# %%
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import random

# %% [markdown]
# ## Pre Set-up

# %% [markdown]
# ### Define Captcha detection

# %%
def detect_captcha(driver):
    try:
        title = driver.find_element(By.XPATH, "//*[contains(text(), 'Additional Verification Required')]").text
        return True
        
    except Exception as e:
        return False

class IpIsBlockedError(Exception):
    def __init__(self, message="Your IP has been blocked. Change your IP and retry."):
        self.message = message
        super().__init__(self.message)

# %% [markdown]
# ### Initialize webdriver (Firefox)

# %%
def init_driver():
    options = webdriver.FirefoxOptions()
    options.set_preference("browser.privatebrowsing.autostart", True)
    # options.add_argument('--headless')
    # options.add_argument('--disable-gpu')
    driver = webdriver.Firefox(options=options)
    return driver

# %% [markdown]
# ### Define position and location

# %%
def get_url(position, location):
    url_template = "https://ca.indeed.com/jobs?q={}&l={}"
    url = url_template.format(position, location)
    return url

url = get_url(position, locations)

# %% [markdown]
# ## 1. Scrape job postings

# %%
driver = init_driver()
time.sleep(3)
dataframe = []
dataframe = pd.DataFrame(columns=["Title", "Company", "Location", "Rating", "Date", "Salary", "Description", "Links"])
jn=0

for i in range(0, postings, 10):
    driver.get(url + "&start=" + str(i))
    driver.implicitly_wait(random.randint(0, 3))

    # Check for CAPTCHA and restart driver if needed
    if detect_captcha(driver):   
        time.sleep(3)
        driver.quit()
        time.sleep(3)
        # triple check whether the ip has been blocked
        check_times = 3
        iter = 0

        while True:
            driver = init_driver()
            driver.get(url + "&start=" + str(i))
            driver.implicitly_wait(random.randint(0,3))

            if not detect_captcha(driver):
                break
            
            time.sleep(3)
            driver.quit()
            time.sleep(3)

            iter = iter + 1
            if iter >= check_times - 1:
                raise IpIsBlockedError(f"IP is blocked. Please use another IP and retry.")

    jobs = driver.find_elements(By.CLASS_NAME, 'job_seen_beacon')

    for job in jobs:
        result_html = job.get_attribute('innerHTML')
        soup = BeautifulSoup(result_html, 'html.parser')
        
        jn += 1
        
        liens = job.find_elements(By.TAG_NAME, "a")
        links = liens[0].get_attribute("href")
        
        title = soup.select('.jobTitle')[0].get_text().strip()
        try:
            company = soup.find_all(attrs={'data-testid': 'company-name'})[0].get_text().strip() 

        except:
            company = 'NaN'
            
        try:
            location = soup.find_all(attrs={'data-testid': 'text-location'})[0].get_text().strip()

        except:
            location = 'NaN'
            
        try:
            salary = soup.select('.salary-snippet-container')[0].get_text().strip()
        except:
            salary = 'NaN'
            
        try:
            rating = soup.find("div",{"class":"companyInfo"}).find("span",{"class":"ratingsDisplay"}).text #scrapfly version
        except:
            rating = 'NaN'
            
        try:
            date = soup.find_all('span',attrs={'data-testid': 'myJobsStateDate'})[0].get_text().strip()
            words_posted_today = ["Today" , "Just", "ongoing"]
            if "ago" in date:
                date_temp = date.split()
                date_temp = date_temp[-3:]
                date = (date_temp[0] + ' ' + date_temp[1] + ' ' + date_temp[2])
            elif any(x in date for x in words_posted_today):
                date = "0 days ago"
            else:
                date = 'NaN'
        except:
            date = 'NaN'
            
        try:
            description = soup.select('.job-snippet')[0].get_text().strip()
        except:
            description = ''
       
        dataframe = pd.concat([dataframe, pd.DataFrame([{'Title': title,
                                          "Company": company,
                                          'Location': location,
                                          'Rating': rating,
                                          'Date': date,
                                          "Salary": salary,
                                          "Description": description,
                                          "Links": links}])], ignore_index=True)
        print("Job number {0:4d} added - {1:s}".format(jn,title))
# Out:
# Job number    1 added - Equity Specialist Anti-Racism & Equity
# Job number    2 added - Social Media Content Specialist
# Job number    3 added - Manager, Content and Social Media
# Job number    4 added - Analyst, Business Intelligence
# Job number    5 added - Intern, Investments
# Job number    6 added - Workforce Analyst
# Job number    7 added - Director, Digital Health & Strategy
# Job number    8 added - Officer, Stewardship and Donor Relations
# Job number    9 added - Advancement Officer - Database and Administration
# Job number   10 added - Sr. Financial Analyst - FP&A
# Job number   11 added - Manager, Food and Beverage Social Media Marketing
# Job number   12 added - Project Coordinator
# Job number   13 added - Fixed Income Financial Planning & Analysis Co-op (Winter & Summer 2025)
# Job number   14 added - Director of Supply Chain
# Job number   15 added - Fraud Reporting Analyst
# Job number   16 added - Marketing Specialist
# Job number   17 added - Senior Analyst, VMO Reporting and Analytics
# Job number   18 added - Manager/Sr. Manager, Marketing
# Job number   19 added - PROJECT COORDINATOR
# Job number   20 added - Client Support Specialist
# Job number   21 added - Data Analytics and Insights Manager
# Job number   22 added - Brand Manager, Tic Tac (Maternity Leave Contract)
# Job number   23 added - Director - Digital Customer Communications
# Job number   24 added - Web Content Optimization Specialist
# Job number   25 added - Digital Marketing - 12-month Contract
# Job number   26 added - Sales Manager, Go Ahead Tours
# Job number   27 added - Junior Media Buyer
# Job number   28 added - Senior Analyst
# Job number   29 added - Marketing Coordinator
# Job number   30 added - Sr. Financial Analyst - Financial Planning & Analysis - Regular Full-time 2024-11185
# Job number   31 added - Marketing Coordinator
# Job number   32 added - Senior Financial Analyst
# Job number   33 added - Senior Financial Analyst
# Job number   34 added - COORDINATOR, FINANCE & ADMINISTRATION
# Job number   35 added - Manager, Accounts Receivable
# Job number   36 added - Audit Manager - Capital Markets Audit
# Job number   37 added - Data Process Analyst
# Job number   38 added - Administrative Assistant - Tory Trauma Program - Regular full-time 2023-4312
# Job number   39 added - Data Analyst
# Job number   40 added - Marketing Intern
# Job number   41 added - Account Manager, Startups, Startups Canada
# Job number   42 added - Manager, Revenue Strategy & Operations
# Job number   43 added - Manager, Sanitation - Corporate Sanitation
# Job number   44 added - Portfolio Financial Consultant
# Job number   45 added - 12 Month Contract - Manager, HRIS

# %%
driver.quit()
dataframe = dataframe.drop_duplicates(subset=['Title', 'Company', 'Location', 'Rating', 'Date', 'Salary', 'Description']).reset_index()
dataframe = dataframe.drop(columns=['index'], axis=1)
dataframe
# Out:
#                                                 Title  \
# 0              Equity Specialist Anti-Racism & Equity
# 1                     Social Media Content Specialist
# 2                   Manager, Content and Social Media
# 2                       Toronto, ON M5B 2L7    NaN          NaN
# 3                               Toronto, ON    NaN          NaN
# 4                       Toronto, ON M5E 1W1    NaN          NaN
# 5                       Toronto, ON M2J 4W8    NaN          NaN
# 6                       Toronto, ON M2J 4W8    NaN          NaN
# 7                               Toronto, ON    NaN          NaN
# 8                               Toronto, ON    NaN          NaN
# 9                       Toronto, ON M5V 1M6    NaN          NaN
# 10               Hybrid work in Toronto, ON    NaN          NaN
# 11               Hybrid work in Toronto, ON    NaN          NaN
# 12                      Toronto, ON M5J 2H7    NaN          NaN
# 13                              Toronto, ON    NaN   4 days ago
# 14     Hybrid work in Etobicoke, ON M8X 2X3    NaN          NaN
# 15       Hybrid work in Toronto, ON M5J 2H7    NaN   4 days ago
# 16       Hybrid work in Toronto, ON M5E 1A4    NaN          NaN
# 17                              Toronto, ON    NaN          NaN
# 18               Hybrid work in Toronto, ON    NaN          NaN
# 19  Hybrid work in Greater Toronto Area, ON    NaN          NaN
# 20                          Mississauga, ON    NaN          NaN
# 21               Hybrid work in Toronto, ON    NaN          NaN
# 22                      Toronto, ON M5V 2V9    NaN          NaN
# 23                              Toronto, ON    NaN          NaN
# 24                      Toronto, ON M5H 0B3    NaN          NaN
# 25       Hybrid work in Toronto, ON M5S 2V1    NaN          NaN
# 26       Hybrid work in Toronto, ON M5A 3C4    NaN          NaN
# 27               Hybrid work in Toronto, ON    NaN          NaN
# 28       Hybrid work in Toronto, ON M5V 2C3    NaN   4 days ago
# 29                      Toronto, ON M4N 3M5    NaN          NaN
# 30               Hybrid work in Toronto, ON    NaN          NaN
# 31                              Toronto, ON    NaN          NaN
# 32                   North York, ON M2N 5X3    NaN   6 days ago
# 33               Hybrid work in Toronto, ON    NaN          NaN
# 34                      Toronto, ON M8X 1C4    NaN          NaN
# 35                              Toronto, ON    NaN          NaN
# 36                              Toronto, ON    NaN          NaN
# 37                  Mississauga, ON L4W 4P4    NaN          NaN
# 38                   North York, ON M6B 1P8    NaN          NaN
# 39                              Toronto, ON    NaN          NaN
# 40                    Remote in Toronto, ON    NaN          NaN
# 41                              Toronto, ON    NaN          NaN
# 42               Hybrid work in Toronto, ON    NaN          NaN
# 43                              Toronto, ON    NaN          NaN
#
#                      Salary Description  \
# 0     $40.72–$50.90 an hour
# 1    $80,594–$97,319 a year
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                       NaN
# 6                       NaN
# 7    $68,000–$89,000 a year
# 8    $65,000–$70,000 a year
# 9                       NaN
# 10                      NaN
# 11                      NaN
# 12   $49,000–$80,200 a year
# 13                      NaN
# 14                      NaN
# 15                      NaN
# 16  $69,001–$120,524 a year
# 17                      NaN
# 18                      NaN
# 19                      NaN
# 20                      NaN
# 21                      NaN
# 22                      NaN
# 23                      NaN
# 24                      NaN
# 25                      NaN
# 26   $40,000–$50,000 a year
# 27                      NaN
# 28   $60,000–$80,000 a year
# 29                      NaN
# 30                      NaN
# 31                      NaN
# 32                      NaN
# 33                      NaN
# 34  $74,800–$138,600 a year
# 35                      NaN
# 36                      NaN
# 37           $55,000 a year
# 38                      NaN
# 39                      NaN
# 40                      NaN
# 41                      NaN
# 42                      NaN
# 43                      NaN
#
#                                                 Links
# 0   https://ca.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# 1   https://ca.indeed.com/pagead/clk?mo=r&ad=-6NYl...
#
    driver.implicitly_wait(random.randint(0,3))

    if detect_captcha(driver):
        
        time.sleep(3)
        driver.quit()
        time.sleep(3)

        # triple check whether the ip has been blocked
        check_times = 3
        iter = 0

        while True:
            driver = init_driver()
            driver.get(link)
            driver.implicitly_wait(random.randint(0,3))

            if not detect_captcha(driver):
                break
            
            time.sleep(3)
            driver.quit()
            time.sleep(3)

            iter = iter + 1
            if iter >= check_times - 1:
                timestamp_str = str(int(time.time()))
                dataframe.to_csv(timestamp_str + '.csv', index=False)
                dataframe.to_pickle(timestamp_str + '.pkl')
                raise IpIsBlockedError(f"IP is blocked. Current work is saved as check_point_{timestamp_str}.csv")
    
    try:
        jd = driver.find_element(By.XPATH, '//div[@id="jobDescriptionText"]').text
    except:
        jd = 'No details provided.'

    dataframe.iloc[index, dataframe.columns.get_loc('Description')] = jd

# %%
driver.quit()
timestamp_str = str(int(time.time()))
dataframe.to_csv('output' + timestamp_str + '.csv', index=False)

# %%
print("Final Output:")
dataframe
# Out:
# Final Output:
#                                                 Title  \
# 0              Equity Specialist Anti-Racism & Equity
# 1                     Social Media Content Specialist
# 2                   Manager, Content and Social Media
# 3                      Analyst, Business Intelligence
# 4                                 Intern, Investments
# 5                                   Workforce Analyst
# 6                 Director, Digital Health & Strategy
# 7            Officer, Stewardship and Donor Relations
# 8   Advancement Officer - Database and Administration
# 9                        Sr. Financial Analyst - FP&A
# 10  Manager, Food and Beverage Social Media Marketing
# 11                                Project Coordinator
# 12  Fixed Income Financial Planning & Analysis Co-...
# 13                           Director of Supply Chain
# 14                            Fraud Reporting Analyst
# 15                               Marketing Specialist
# 16        Senior Analyst, VMO Reporting and Analytics
# 17                     Manager/Sr. Manager, Marketing
# 18                                PROJECT COORDINATOR
# 19                          Client Support Specialist
# 20                Data Analytics and Insights Manager
# 21  Brand Manager, Tic Tac (Maternity Leave Contract)
# 22         Director - Digital Customer Communications
# 23                Web Content Optimization Specialist
# 24              Digital Marketing - 12-month Contract
# 25                      Sales Manager, Go Ahead Tours
# 26                                 Junior Media Buyer
# 27                                     Senior Analyst
# 28                              Marketing Coordinator
# 29  Sr. Financial Analyst - Financial Planning & A...
# 30                           Senior Financial Analyst
# 31                           Senior Financial Analyst
# 32              COORDINATOR, FINANCE & ADMINISTRATION
# 33                       Manager, Accounts Receivable
# 34              Audit Manager - Capital Markets Audit
# 35                               Data Process Analyst
# 36  Administrative Assistant - Tory Trauma Program...
# 37                                       Data Analyst
# 38                                   Marketing Intern
# 39         Account Manager, Startups, Startups Canada
# 40             Manager, Revenue Strategy & Operations
# 41         Manager, Sanitation - Corporate Sanitation
# 42                     Portfolio Financial Consultant
# 43                  12 Month Contract - Manager, HRIS
#
#                                              Company  \
# 0                               Unity Health Toronto
# 1                                     ACTRA National
# 2                                         Mastercard
# 3                                     Great Canadian
# 4                                            CAPREIT
# 5                    Shoppers Drug Mart / Pharmaprix
# 6                    Shoppers Drug Mart / Pharmaprix
# 7                               Unity Health Toronto
# 8                               St. Clement's School
# 9                               Indigo Books & Music
# 10                                      Four Seasons
# 11  Ministry of Labour, Immigration, Training and...
# 12                                    SLC Management
# 13                      Ghost Kitchens International
# 14                             Meridian Credit Union
# 15                         Cornerstone Physiotherapy
# 16                                              LCBO
# 17                                              Amex
# 18                                   City of Toronto
# 19                                     AutoTrader.ca
# 20                               Bayshore HealthCare
# 21                                           FERRERO
# 22                          Loblaw Companies Limited
# 23                                   York University
# 24                                                EY
# 25                                 EF Go Ahead Tours
# 26                                    Kingstar Media
# 27                             Rogers Communications
# 28                        The Sponsorship Collective
# 29                 Sunnybrook Health Sciences Centre
# 30                             Rogers Communications
# 31                                              Amex
# 32           Ontario Professional Planners Institute
# 33                                          Caseware
# 34                               BMO Financial Group
# 35                              Neighbourly Pharmacy
# 36                 Sunnybrook Health Sciences Centre
# 37             CloudMD Software & Services Inc - CAN
# 38                                      Studio Munge
# 39                  Amazon Web Services Canada, Inc.
# 40                                         OpenTable
# 41                                 Give and Go Foods
# 42                                              CIBC
# 43                 Coca-Cola Canada Bottling Limited
#
#                                    Location Rating         Date  \
# 0                               Toronto, ON    NaN          NaN
# 1                       Toronto, ON M4Y 2G1    NaN  12 days ago
# 2                       Toronto, ON M5B 2L7    NaN          NaN
# 3                               Toronto, ON    NaN          NaN
# 4                       Toronto, ON M5E 1W1    NaN          NaN
# 5                       Toronto, ON M2J 4W8    NaN          NaN
# 6                       Toronto, ON M2J 4W8    NaN          NaN
# 7                               Toronto, ON    NaN          NaN
# 8                               Toronto, ON    NaN          NaN
# 9                       Toronto, ON M5V 1M6    NaN          NaN
# 10               Hybrid work in Toronto, ON    NaN          NaN
# 11               Hybrid work in Toronto, ON    NaN          NaN
# 12                      Toronto, ON M5J 2H7    NaN          NaN
# 13                              Toronto, ON    NaN   4 days ago
# 14     Hybrid work in Etobicoke, ON M8X 2X3    NaN          NaN
# 15       Hybrid work in Toronto, ON M5J 2H7    NaN   4 days ago
# 16       Hybrid work in Toronto, ON M5E 1A4    NaN          NaN
# 17                              Toronto, ON    NaN          NaN
# 18               Hybrid work in Toronto, ON    NaN          NaN
# 19  Hybrid work in Greater Toronto Area, ON    NaN          NaN
# 20                          Mississauga, ON    NaN          NaN
# 21               Hybrid work in Toronto, ON    NaN          NaN
# 22                      Toronto, ON M5V 2V9    NaN          NaN
# 23                              Toronto, ON    NaN          NaN
# 24                      Toronto, ON M5H 0B3    NaN          NaN
# 25       Hybrid work in Toronto, ON M5S 2V1    NaN          NaN
# 26       Hybrid work in Toronto, ON M5A 3C4    NaN          NaN
# 27               Hybrid work in Toronto, ON    NaN          NaN
# 28       Hybrid work in Toronto, ON M5V 2C3    NaN   4 days ago
# 29                      Toronto, ON M4N 3M5    NaN          NaN
# 30               Hybrid work in Toronto, ON    NaN          NaN
# 31                              Toronto, ON    NaN          NaN
# 32                   North York, ON M2N 5X3    NaN   6 days ago
# 33               Hybrid work in Toronto, ON    NaN          NaN
# 34                      Toronto, ON M8X 1C4    NaN          NaN
# 35                              Toronto, ON    NaN          NaN
# 36                              Toronto, ON    NaN          NaN
# 37                  Mississauga, ON L4W 4P4    NaN          NaN
# 38                   North York, ON M6B 1P8    NaN          NaN
# 39                              Toronto, ON    NaN          NaN
# 40                    Remote in Toronto, ON    NaN          NaN
# 41                              Toronto, ON    NaN          NaN
# 42               Hybrid work in Toronto, ON    NaN          NaN
# 43                              Toronto, ON    NaN          NaN
#
#                      Salary  \
# 0     $40.72–$50.90 an hour
# 1    $80,594–$97,319 a year
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                       NaN
# 6                       NaN
# 7    $68,000–$89,000 a year
# 8    $65,000–$70,000 a year
# 9                       NaN
# 10                      NaN
# 11                      NaN
# 12   $49,000–$80,200 a year
# 13                      NaN
# 14                      NaN
# 15                      NaN
# 16  $69,001–$120,524 a year
# 17                      NaN
# 18                      NaN
# 19                      NaN
# 20                      NaN
# 21                      NaN
# 22                      NaN
# 23                      NaN
# 24                      NaN
# 25                      NaN
# 26   $40,000–$50,000 a year
# 27                      NaN
# 28   $60,000–$80,000 a year
# 29                      NaN
# 30                      NaN
# 31                      NaN
# 32                      NaN
# 33                      NaN
# 34  $74,800–$138,600 a year
# 35                      NaN
# 36                      NaN
# 37           $55,000 a year
# 38                      NaN
# 39                      NaN
# 40                      NaN
# 41                      NaN
# 42                      NaN
# 43                      NaN
#
#                                           Description  \
# 0   Unity Health Toronto’s vision is to create the...
# 1   ACTRA (Alliance of Canadian Cinema, Television...
# 2   Our Purpose\nWe work to connect and power an i...
# 3   Position Summary:\nUnder the general direction...
# 4   :\n\nTitle: Intern, Investments (Winter 2025)\...
# 5   Referred applicants must not apply directly to...
# 6   Referred applicants must not apply directly to...
# 7   DEPARTMENT SUMMARY\nSt. Michael's Hospital Fou...
# 8   St. Clement’s School is currently looking for ...
# 9   Company Description\n\nDedicated to telling st...
# 10  About Four Seasons:\nFour Seasons is powered b...
# 11  Passionate about digital transformation? This ...
# 12  SLC Management is a growing global asset manag...
# 13  Job Title: Director of Supply Chain\nReports t...
# 14  About this opportunity\nAt Meridian our aspira...
# 15  Who We Are\nCornerstone Physiotherapy is regar...
# 16  Location Address:\n100 Queens Quay East, 9th F...
# 17  You Lead the Way. We’ve Got Your Back.\nWith t...
# 18  Job ID: 48593\nDivision & Section: People & Eq...
# 19  TRADER Corporation is a trusted Canadian leade...
# 20  DUTIES AND RESPONSIBILITIES\nTranslating busin...
# 21  Job Location: Toronto\nCompany description\nFe...
# 22  Referred applicants should not apply directly ...
# 23  Purpose:\nReporting to the Director, Strategic...
# 24  At EY, you’ll have the chance to build a caree...
# 25  Sales Manager\nGo Ahead Tours (GAT) Canada\nDi...
# 26  Job Title\nJunior Media Buyer\nLocation\nToron...
# 27  Looking to join a growing financial services t...
# 28  Marketing Coordinator\nTHE SPONSORSHIP COLLECT...
# 29  Summary of Duties\nThe Finance department of S...
# 30  We are committed to connecting Canadians throu...
# 31  You Lead the Way. We’ve Got Your Back.\nWith t...
# 32  Elevate your career as a Coordinator of Financ...
# 33  Caseware is one of Canada's original Fintech c...
# 34  100 King Street West Toronto Ontario,M5X 1A1\n...
# 35  Neighbourly Pharmacy is looking for a Data Pro...
# 36  Reporting to The Operational Director, this ro...
# 37  Who We Are\nAre you looking to further develop...
# 38  MARKETING INTERN at STUDIO MUNGE (PART-TIME)\n...
# 39  5+ years of full sales cycle, technology sales...
# 40  With millions of diners, tens of thousands of ...
# 41  Give & Go Prepared Foods Corp.is a proud membe...
# 42  We’re building a relationship-oriented bank fo...
# 43  Facility Location- Toronto\nEmployee Type - Co...
#
#                                                 Links
# 0   https://ca.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# 